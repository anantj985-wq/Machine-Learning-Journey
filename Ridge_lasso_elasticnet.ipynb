# %%
# Code for implementing ridge by own

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_diabetes

data = load_diabetes()

# %%
print(data.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
X=data.data
y=data.target

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=45)

# %%
from sklearn.linear_model import LinearRegression
L=LinearRegression()

# %%
L.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=L.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error
print("R2 score",r2_score(y_test,y_pred))
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# R2 score 0.5188113124539249
# RMSE 48.72713760953252

# %%
from sklearn.linear_model import Ridge
R = Ridge(alpha =0.1,solver = 'cholesky')

# %%
R.fit(X_train,y_train)
# Out:
# Ridge(alpha=0.1, solver='cholesky')

# %%
y_pred1=R.predict(X_test)

# %%
print("R2 score",r2_score(y_test,y_pred1))
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred1)))
# Out:
# R2 score 0.5208421054129915
# RMSE 48.62420568515607

# %%
print(R.coef_)
print(R.intercept_)
# Out:
# [  31.03389163 -204.8305909   464.8963454   304.96414918  -95.76037039
#   -87.52969228 -183.81809293  147.49794012  425.85392451  110.21559915]
# 152.07141290172817

# %%
class MeraRr:
    def __init__(self,alpha=0.1):
        self.alpha = alpha
        self.coef_= None
        self.intercept_= None
    def fit(self,X_train,y_train):
        X_train = np.insert(X_train,0,1,axis=1)
        I = np.identity(X_train.shape[1])
        I[0][0]=0 # in scikit learn the a11 value is 0 so for same answer as scikit we have to assign it.
        result = np.linalg.inv(np.dot(X_train.T,X_train) + self.alpha * I).dot(X_train.T).dot(y_train)
        self.intercept_ =result[0]
        self.coef_ = result[1:]
        
    def predict(self,X_test):
        return np.dot(X_test,self.coef_) + self.intercept_

# %%
reg=MeraRr()
reg.fit(X_train,y_train)
y_pred = reg.predict(X_test)
print("R2 score",r2_score(y_test,y_pred))
print(reg.coef_)
print(reg.intercept_)
# Out:
# R2 score 0.5208421054129913
# [  31.03389163 -204.8305909   464.8963454   304.96414918  -95.76037039
#   -87.52969228 -183.81809293  147.49794012  425.85392451  110.21559915]
# 152.0714129017282

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso,ElasticNet

# %%
r1=LinearRegression()
r1.fit(X_train,y_train)
y_prediction = r1.predict(X_test)
r2_score(y_test,y_prediction)
# Out:
# 0.5188113124539249

# %%
ridge_pred = Ridge(alpha=0.1)
ridge_pred.fit(X_train,y_train)
y_pred =ridge_pred.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.5208421054129915

# %%
Lasso_pred = Lasso(alpha=0.01)
Lasso_pred.fit(X_train,y_train)
y_pred =Lasso_pred.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.523981729427635

# %%
ElasticNet_pred = ElasticNet(alpha=0.005,l1_ratio = 0.9)
ElasticNet_pred.fit(X_train,y_train)
y_pred =ElasticNet_pred.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.5171428241516913
