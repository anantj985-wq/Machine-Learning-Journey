# %%
import numpy as np

# %%
x=np.random.randn(10,1)
print(x)
# Out:
# [[ 0.54675493]
#  [-1.72742441]
#  [ 0.89690702]
#  [-0.48110951]
#  [-0.84007648]
#  [ 0.71813563]
#  [-0.29165787]
#  [-0.09872101]
#  [-0.8196587 ]
#  [-0.593542  ]]

# %%
y=4 * x + np.random.rand()
#parameter
w=0
b=0

# %%
#hyperparameter
lr=0.01

# %%
#create gradient descent function
def grad_desc(x,y,w,b,lr):
    dldw=0.0
    dldb=0.0
    N=.shape(0) # for average divide by no of items
    #loss =(y-yhat)**2
    for xi,yi in zip(x,y):
        dldw += -2*xi(yi-(wxi+b))
        dldb += -2(yi-(wxi+b))

    # make an update
    w = w -lr*(1/N)*dldw
    b = b -lr*(1/N)*dldb
    return w,b
# Out:
# <>:9: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# <>:9: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# /var/folders/7l/_41x2pg9675_jvhj0fgs5tcc0000gn/T/ipykernel_1426/1384572947.py:9: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
#   dldb += -2(yi-(wxi+b))

# %%
# iteratively make updates
for epoch in range(400):
    w,b=grad_desc(x,y,w,b,lr)
    yhat=w*x+b
    loss = np.divide(np.sum((y-yhat)**2,axis=0),N)
    print(f'{epoch} loss is {loss},parameters w{w},b:{b}')
    print(w,b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 # iteratively make updates
#       2 for epoch in range(400):
# ----> 3     w,b=grad_desc(x,y,w,b,lr)
#       4     yhat=w*x+b
#       5     loss = np.divide(np.sum((y-yhat)**2,axis=0),N)
#
# Cell In[6], line 5, in grad_desc(x, y, w, b, lr)
#       3 dldw=0.0
#       4 dldb=0.0
# ----> 5 N=X.shape(0) # for average divide by no of items
#       6 #loss =(y-yhat)**2
#       7 for xi,yi in zip(x,y):
#
# NameError: name 'X' is not defined
